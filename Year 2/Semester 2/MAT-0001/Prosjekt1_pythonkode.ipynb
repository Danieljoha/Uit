# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(-2, 2, 100)

def funksjon(x):
    return 1.5*x -3


fig, ax = plt.subplots()
ax.plot(x, funksjon(x))
ax.plot(x, 0*x)
ax.vlines(-2, funksjon(-2), 0, color='r')
